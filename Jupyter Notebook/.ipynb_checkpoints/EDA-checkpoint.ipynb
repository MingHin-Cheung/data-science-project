# %%
# Import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("cleaned_data.csv", index_col=0)

# %%
df.head()
# Out:
#          CRASH DATE CRASH TIME    BOROUGH   LATITUDE  LONGITUDE  \
# 1603651  08/26/2013      20:40   BROOKLYN  40.629987 -73.971568
# 1055943  03/24/2016      12:02  MANHATTAN  40.751827 -73.984770
# 1777275  10/31/2012      21:45  MANHATTAN  40.793552 -73.945325
# 1251336  05/25/2015       4:30     QUEENS  40.692648 -73.833018
# 1057011  03/27/2016      14:25   BROOKLYN  40.681213 -73.847272
#
#          NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# 1603651                        1.0                       0.0
# 1055943                        0.0                       0.0
# 1777275                        0.0                       0.0
# 1251336                        0.0                       0.0
# 1057011                        0.0                       0.0
#
#          NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# 1603651                              0                             0
# 1055943                              0                             0
# 1777275                              0                             0
# 1251336                              0                             0
# 1057011                              0                             0
#
#          NUMBER OF CYCLIST INJURED  NUMBER OF CYCLIST KILLED  \
# 1603651                          1                         0
# 1055943                          0                         0
# 1777275                          0                         0
# 1251336                          0                         0
# 1057011                          0                         0
#
#          NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED
# 1603651                           0                          0
# 1055943                           0                          0
# 1777275                           0                          0
# 1251336                           0                          0
# 1057011                           0                          0

# %%
df.shape
# Out:
# (34521, 13)

# %%
df.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'LATITUDE', 'LONGITUDE',
#        'NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED',
#        'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED',
#        'NUMBER OF CYCLIST INJURED', 'NUMBER OF CYCLIST KILLED',
#        'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# CRASH DATE                       0
# CRASH TIME                       0
# BOROUGH                          0
# LATITUDE                         0
# LONGITUDE                        0
# NUMBER OF PERSONS INJURED        0
# NUMBER OF PERSONS KILLED         0
# NUMBER OF PEDESTRIANS INJURED    0
# NUMBER OF PEDESTRIANS KILLED     0
# NUMBER OF CYCLIST INJURED        0
# NUMBER OF CYCLIST KILLED         0
# NUMBER OF MOTORIST INJURED       0
# NUMBER OF MOTORIST KILLED        0
# dtype: int64

# %%
#Statistical Summary of our data
df.describe()
# Out:
#            LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  34521.000000  34521.000000               34521.000000
# mean      40.681210    -73.847264                   0.268098
# std        1.279731      2.320208                   0.660501
# min        0.000000    -74.253031                   0.000000
# 25%       40.667963    -73.976134                   0.000000
# 50%       40.716649    -73.927826                   0.000000
# 75%       40.764377    -73.865234                   0.000000
# max       40.912468      0.000000                  24.000000
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              34521.000000                   34521.000000
# mean                   0.001535                       0.058892
# std                    0.039153                       0.257184
# min                    0.000000                       0.000000
# 25%                    0.000000                       0.000000
# 50%                    0.000000                       0.000000
# 75%                    0.000000                       0.000000
# max                    1.000000                      15.000000
#
#        NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  \
# count                  34521.000000               34521.000000
# mean                       0.000927                   0.026824
# std                        0.030433                   0.163178
# min                        0.000000                   0.000000
# 25%                        0.000000                   0.000000
# 50%                        0.000000                   0.000000
# 75%                        0.000000                   0.000000
# max                        1.000000                   2.000000
#
#        NUMBER OF CYCLIST KILLED  NUMBER OF MOTORIST INJURED  \
# count              34521.000000                34521.000000
# mean                   0.000087                    0.181165
# std                    0.009322                    0.610904
# min                    0.000000                    0.000000
# 25%                    0.000000                    0.000000
# 50%                    0.000000                    0.000000
# 75%                    0.000000                    0.000000
# max                    1.000000                   24.000000
#
#        NUMBER OF MOTORIST KILLED
# count               34521.000000
# mean                    0.000492
# std                     0.022186
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     0.000000
# max                     1.000000

# %%
#Checking categorical features in our dataset.

categorical_features = df.select_dtypes(include=[np.object])
categorical_features.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH'], dtype='object')

# %%
#Heatmap of our data

fig, ax = plt.subplots(figsize=(12,6))
sns.heatmap(df.corr(), annot=True, cmap="Reds" )
# Out:
# <AxesSubplot:>

# %% [markdown]
# __Inference:__ The above heatmap shows the correlation of numerical features in our data. The correlation coefficient is a measure ranging from -1 to 1 (with 1 being the maximum value and -1 being the smallest):<br>
# * The Number closer to zero indicates a lower correlation (precise 0 implying no significant
# relation).
# *	The Number around +1 to one indicates a more positive correlation.
# *	The Number around -1 implies a more negative correlation.

# %%
df.max()
# Out:
# CRASH DATE                          12/31/2020
# CRASH TIME                                9:59
# BOROUGH                          STATEN ISLAND
# LATITUDE                             40.912468
# LONGITUDE                                  0.0
# NUMBER OF PERSONS INJURED                 24.0
# NUMBER OF PERSONS KILLED                   1.0
# NUMBER OF PEDESTRIANS INJURED               15
# NUMBER OF PEDESTRIANS KILLED                 1
# NUMBER OF CYCLIST INJURED                    2
# NUMBER OF CYCLIST KILLED                     1
# NUMBER OF MOTORIST INJURED                  24
# NUMBER OF MOTORIST KILLED                    1
# dtype: object

# %%
df.min()
# Out:
# CRASH DATE                       01/01/2013
# CRASH TIME                             0:00
# BOROUGH                               BRONX
# LATITUDE                                0.0
# LONGITUDE                        -74.253031
# NUMBER OF PERSONS INJURED               0.0
# NUMBER OF PERSONS KILLED                0.0
# NUMBER OF PEDESTRIANS INJURED             0
# NUMBER OF PEDESTRIANS KILLED              0
# NUMBER OF CYCLIST INJURED                 0
# NUMBER OF CYCLIST KILLED                  0
# NUMBER OF MOTORIST INJURED                0
# NUMBER OF MOTORIST KILLED                 0
# dtype: object

# %% [markdown]
# ### Checking skewness ###

# %%
#Checking skewness
df.skew()
# Out:
# LATITUDE                         -31.641179
# LONGITUDE                         31.758024
# NUMBER OF PERSONS INJURED          5.561738
# NUMBER OF PERSONS KILLED          25.463651
# NUMBER OF PEDESTRIANS INJURED      9.343793
# NUMBER OF PEDESTRIANS KILLED      32.800544
# NUMBER OF CYCLIST INJURED          6.036673
# NUMBER OF CYCLIST KILLED         107.261363
# NUMBER OF MOTORIST INJURED         6.707766
# NUMBER OF MOTORIST KILLED         45.031364
# dtype: float64

# %% [markdown]
# ### Checking Kurtosis ###

# %%
#Checking kurtosis
df.kurt()
# Out:
# LATITUDE                          1002.967017
# LONGITUDE                         1007.911685
# NUMBER OF PERSONS INJURED           88.352675
# NUMBER OF PERSONS KILLED           646.434960
# NUMBER OF PEDESTRIANS INJURED      345.129047
# NUMBER OF PEDESTRIANS KILLED      1073.937894
# NUMBER OF CYCLIST INJURED           35.858133
# NUMBER OF CYCLIST KILLED         11503.666377
# NUMBER OF MOTORIST INJURED         112.085036
# NUMBER OF MOTORIST KILLED         2025.941149
# dtype: float64

# %% [markdown]
# ### Cities with their collision numbers ###

# %%
#Cities with their crime numbers
fig, ax = plt.subplots(figsize=(12,6))
sns.countplot(x=df['BOROUGH'], data=df, ax=ax)
plt.show()

# %% [markdown]
# ## Inference:
# - Brooklyn had the most number of collisions as compared to other boroughs while Staten Island had the least.

# %%
#Adding a new column for years
df["CRASH DATE"] = pd.to_datetime(df["CRASH DATE"])
df["year"] = df["CRASH DATE"].dt.year
df["year"].unique()
# Out:
# array([2013, 2016, 2012, 2015, 2014, 2018, 2019, 2020, 2017, 2021],
#       dtype=int64)

# %%
#Adding a month column for months
df["month"] = df["CRASH DATE"].dt.month
df["month"].unique()
# Out:
# array([ 8,  3, 10,  5,  7, 12,  9,  4, 11,  1,  6,  2], dtype=int64)

# %% [markdown]
# ### Checking for number of collisions by year ###

# %%
#Checking for number of collisions by year
fig, ax = plt.subplots(figsize=(12,6))
sns.countplot(x=df['year'], data=df, ax=ax)
plt.show()

# %% [markdown]
# ## Inference:
# - As we can see from this graph, the year 2019 has the most number of collisions where the year 2016 has least.

# %% [markdown]
# ### Checking for number of collisions by month ###

# %%
#Checking for number of collisions by month
fig, ax = plt.subplots(figsize=(12,6))
sns.countplot(x=df['month'], data=df, ax=ax)
plt.show()

# %% [markdown]
# ## Inference:
# - As we can see here, the most number of collisions occured in October overall which is numbered as 10 in this graph.

# %%
#Cities with most number of deaths
killed_by_borough = df.groupby("BOROUGH")[["NUMBER OF PERSONS KILLED", "NUMBER OF PEDESTRIANS KILLED",\
                                           "NUMBER OF CYCLIST KILLED"]].sum()
print(killed_by_borough)
killed_by_borough.plot.bar(figsize=(12,6))
# Out:
#                NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS KILLED  \
# BOROUGH
# BRONX                               5.0                             3
# BROOKLYN                           21.0                            13
# MANHATTAN                          12.0                            10
# QUEENS                             15.0                             6
# STATEN ISLAND                       0.0                             0
#
#                NUMBER OF CYCLIST KILLED
# BOROUGH
# BRONX                                 0
# BROOKLYN                              2
# MANHATTAN                             0
# QUEENS                                1
# STATEN ISLAND                         0
# <AxesSubplot:xlabel='BOROUGH'>

# %% [markdown]
# ## Inference:
# - As we can see from the above graph, most deaths occured in Queens and Brooklyn.

# %%
persons_killed_by_year = df.groupby("year")["NUMBER OF PERSONS KILLED"].sum()
persons_killed_by_year
# Out:
# year
# 2012    4.0
# 2013    8.0
# 2014    3.0
# 2015    9.0
# 2016    7.0
# 2017    3.0
# 2018    5.0
# 2019    4.0
# 2020    6.0
# 2021    4.0
# Name: NUMBER OF PERSONS KILLED, dtype: float64

# %% [markdown]
# ### Pie chart for persons killed by year ###

# %%
#Pie chart for persons killed by year
fig, ax  = plt.subplots(figsize=(16, 8))
fig.suptitle('Persons killed by year', size = 14, color = "black")
ax = plt.pie(persons_killed_by_year, labels=persons_killed_by_year.index,
       autopct='%1.0f%%',
       pctdistance=0.9)

# %% [markdown]
# ## Inference:
# - From the above graph, we can see that the highest percentage of deaths occured in 2012, 2013 and 2017.
