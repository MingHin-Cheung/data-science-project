# %% [markdown]
# # Exploratory Data Analysis

# %%
# Import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(".././Dataset/cleaned_data.csv", index_col=0)

# %%
df.head()
# Out:
#          CRASH DATE CRASH TIME        BOROUGH   LATITUDE  LONGITUDE  \
# 1732507  02/05/2013      14:00         QUEENS  40.740068 -73.935449
# 1502389  03/08/2014      23:09         QUEENS  40.740540 -73.897309
# 1573470  10/09/2013      13:40      MANHATTAN  40.769272 -73.981021
# 837460   03/01/2017      10:45  STATEN ISLAND  40.560535 -74.180420
# 1699981  03/27/2013      20:00          BRONX  40.885587 -73.905887
#
#          NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# 1732507                        0.0                       0.0
# 1502389                        0.0                       0.0
# 1573470                        0.0                       0.0
# 837460                         0.0                       0.0
# 1699981                        0.0                       0.0
#
#          NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# 1732507                              0                             0
# 1502389                              0                             0
# 1573470                              0                             0
# 837460                               0                             0
# 1699981                              0                             0
#
#          NUMBER OF CYCLIST INJURED  NUMBER OF CYCLIST KILLED  \
# 1732507                          0                         0
# 1502389                          0                         0
# 1573470                          0                         0
# 837460                           0                         0
# 1699981                          0                         0
#
#          NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED
# 1732507                           0                          0
# 1502389                           0                          0
# 1573470                           0                          0
# 837460                            0                          0
# 1699981                           0                          0

# %%
df.shape
# Out:
# (34431, 13)

# %%
df.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'LATITUDE', 'LONGITUDE',
#        'NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED',
#        'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED',
#        'NUMBER OF CYCLIST INJURED', 'NUMBER OF CYCLIST KILLED',
#        'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# CRASH DATE                       0
# CRASH TIME                       0
# BOROUGH                          0
# LATITUDE                         0
# LONGITUDE                        0
# NUMBER OF PERSONS INJURED        0
# NUMBER OF PERSONS KILLED         0
# NUMBER OF PEDESTRIANS INJURED    0
# NUMBER OF PEDESTRIANS KILLED     0
# NUMBER OF CYCLIST INJURED        0
# NUMBER OF CYCLIST KILLED         0
# NUMBER OF MOTORIST INJURED       0
# NUMBER OF MOTORIST KILLED        0
# dtype: int64

# %%
#Statistical Summary of our data
df.describe()
# Out:
#            LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  34431.000000  34431.000000               34431.000000
# mean      40.667725    -73.822722                   0.267143
# std        1.473261      2.671908                   0.648258
# min        0.000000    -74.251830                   0.000000
# 25%       40.667725    -73.975882                   0.000000
# 50%       40.716141    -73.928115                   0.000000
# 75%       40.764650    -73.865132                   0.000000
# max       40.912638      0.000000                  27.000000
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              34431.000000                   34431.000000
# mean                   0.001278                       0.061137
# std                    0.036530                       0.292530
# min                    0.000000                       0.000000
# 25%                    0.000000                       0.000000
# 50%                    0.000000                       0.000000
# 75%                    0.000000                       0.000000
# max                    2.000000                      27.000000
#
#        NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  \
# count                  34431.000000               34431.000000
# mean                       0.000755                   0.027243
# std                        0.027470                   0.164391
# min                        0.000000                   0.000000
# 25%                        0.000000                   0.000000
# 50%                        0.000000                   0.000000
# 75%                        0.000000                   0.000000
# max                        1.000000                   3.000000
#
#        NUMBER OF CYCLIST KILLED  NUMBER OF MOTORIST INJURED  \
# count              34431.000000                34431.000000
# mean                   0.000087                    0.177398
# std                    0.009334                    0.580606
# min                    0.000000                    0.000000
# 25%                    0.000000                    0.000000
# 50%                    0.000000                    0.000000
# 75%                    0.000000                    0.000000
# max                    1.000000                   13.000000
#
#        NUMBER OF MOTORIST KILLED
# count               34431.000000
# mean                    0.000436
# std                     0.022216
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     0.000000
# max                     2.000000

# %%
#Checking categorical features in our dataset.

categorical_features = df.select_dtypes(include=[np.object])
categorical_features.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH'], dtype='object')

# %%
#Heatmap of our data

fig, ax = plt.subplots(figsize=(12,6))
sns.heatmap(df.corr(), annot=True, cmap="Reds" )
# Out:
# <AxesSubplot:>

# %% [markdown]
# __Inference:__ The above heatmap shows the correlation of numerical features in our data. The correlation coefficient is a measure ranging from -1 to 1 (with 1 being the maximum value and -1 being the smallest):<br>
# * The Number closer to zero indicates a lower correlation (precise 0 implying no significant
# relation).
# *	The Number around +1 to one indicates a more positive correlation.
# *	The Number around -1 implies a more negative correlation.

# %%
df.max()
# Out:
# CRASH DATE                          12/31/2020
# CRASH TIME                                9:59
# BOROUGH                          STATEN ISLAND
# LATITUDE                             40.912638
# LONGITUDE                                  0.0
# NUMBER OF PERSONS INJURED                 27.0
# NUMBER OF PERSONS KILLED                   2.0
# NUMBER OF PEDESTRIANS INJURED               27
# NUMBER OF PEDESTRIANS KILLED                 1
# NUMBER OF CYCLIST INJURED                    3
# NUMBER OF CYCLIST KILLED                     1
# NUMBER OF MOTORIST INJURED                  13
# NUMBER OF MOTORIST KILLED                    2
# dtype: object

# %%
df.min()
# Out:
# CRASH DATE                       01/01/2013
# CRASH TIME                             0:00
# BOROUGH                               BRONX
# LATITUDE                                0.0
# LONGITUDE                         -74.25183
# NUMBER OF PERSONS INJURED               0.0
# NUMBER OF PERSONS KILLED                0.0
# NUMBER OF PEDESTRIANS INJURED             0
# NUMBER OF PEDESTRIANS KILLED              0
# NUMBER OF CYCLIST INJURED                 0
# NUMBER OF CYCLIST KILLED                  0
# NUMBER OF MOTORIST INJURED                0
# NUMBER OF MOTORIST KILLED                 0
# dtype: object

# %% [markdown]
# ### Checking skewness ###

# %%
#Checking skewness
df.skew()
# Out:
# LATITUDE                         -27.491930
# LONGITUDE                         27.567921
# NUMBER OF PERSONS INJURED          5.413363
# NUMBER OF PERSONS KILLED          29.688656
# NUMBER OF PEDESTRIANS INJURED     25.922355
# NUMBER OF PEDESTRIANS KILLED      36.350861
# NUMBER OF CYCLIST INJURED          6.023362
# NUMBER OF CYCLIST KILLED         107.121426
# NUMBER OF MOTORIST INJURED         4.755281
# NUMBER OF MOTORIST KILLED         55.568733
# dtype: float64

# %% [markdown]
# ### Checking Kurtosis ###

# %%
#Checking kurtosis
df.kurt()
# Out:
# LATITUDE                           755.982392
# LONGITUDE                          758.772580
# NUMBER OF PERSONS INJURED          103.657086
# NUMBER OF PERSONS KILLED           939.047238
# NUMBER OF PEDESTRIANS INJURED     2109.515740
# NUMBER OF PEDESTRIANS KILLED      1319.461763
# NUMBER OF CYCLIST INJURED           36.595452
# NUMBER OF CYCLIST KILLED         11473.666376
# NUMBER OF MOTORIST INJURED          33.378852
# NUMBER OF MOTORIST KILLED         3450.811958
# dtype: float64

# %% [markdown]
# ### Cities with their collision numbers ###

# %%
#Cities with their crime numbers
fig, ax = plt.subplots(figsize=(12,6))
sns.countplot(x=df['BOROUGH'], data=df, ax=ax)
plt.show()

# %% [markdown]
# ## Inference:
# - Brooklyn had the most number of collisions as compared to other boroughs while Staten Island had the least.

# %%
#Adding a new column for years
df["CRASH DATE"] = pd.to_datetime(df["CRASH DATE"])
df["year"] = df["CRASH DATE"].dt.year
df["year"].unique()
# Out:
# array([2013, 2014, 2017, 2015, 2018, 2012, 2019, 2020, 2016, 2021],
#       dtype=int64)

# %%
#Adding a month column for months
df["month"] = df["CRASH DATE"].dt.month
df["month"].unique()
# Out:
# array([ 2,  3, 10,  9,  4,  7,  8,  1,  6, 11, 12,  5], dtype=int64)

# %% [markdown]
# ### Checking for number of collisions by year ###

# %%
#Checking for number of collisions by year
fig, ax = plt.subplots(figsize=(12,6))
sns.countplot(x=df['year'], data=df, ax=ax)
plt.show()

# %% [markdown]
# ## Inference:
# - As we can see from this graph, the year 2019 has the most number of collisions where the year 2016 has least.

# %% [markdown]
# ### Checking for number of collisions by month ###

# %%
#Checking for number of collisions by month
fig, ax = plt.subplots(figsize=(12,6))
sns.countplot(x=df['month'], data=df, ax=ax)
plt.show()

# %% [markdown]
# ## Inference:
# - As we can see here, the most number of collisions occured in October overall which is numbered as 10 in this graph.

# %%
#Cities with most number of deaths
killed_by_borough = df.groupby("BOROUGH")[["NUMBER OF PERSONS KILLED", "NUMBER OF PEDESTRIANS KILLED",\
                                           "NUMBER OF CYCLIST KILLED"]].sum()
print(killed_by_borough)
killed_by_borough.plot.bar(figsize=(12,6))
# Out:
#                NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS KILLED  \
# BOROUGH
# BRONX                              10.0                             6
# BROOKLYN                           10.0                             7
# MANHATTAN                           8.0                             7
# QUEENS                             13.0                             5
# STATEN ISLAND                       3.0                             1
#
#                NUMBER OF CYCLIST KILLED
# BOROUGH
# BRONX                                 0
# BROOKLYN                              1
# MANHATTAN                             0
# QUEENS                                2
# STATEN ISLAND                         0
# <AxesSubplot:xlabel='BOROUGH'>

# %% [markdown]
# ## Inference:
# - As we can see from the above graph, most deaths occured in Queens and Brooklyn.

# %%
persons_killed_by_year = df.groupby("year")["NUMBER OF PERSONS KILLED"].sum()
persons_killed_by_year
# Out:
# year
# 2012    5.0
# 2013    7.0
# 2014    6.0
# 2015    5.0
# 2016    7.0
# 2017    1.0
# 2018    5.0
# 2019    5.0
# 2020    1.0
# 2021    2.0
# Name: NUMBER OF PERSONS KILLED, dtype: float64

# %% [markdown]
# ### Pie chart for persons killed by year ###

# %%
#Pie chart for persons killed by year
fig, ax  = plt.subplots(figsize=(16, 8))
fig.suptitle('Persons killed by year', size = 14, color = "black")
ax = plt.pie(persons_killed_by_year, labels=persons_killed_by_year.index,
       autopct='%1.0f%%',
       pctdistance=0.9)

# %% [markdown]
# ## Inference:
# - From the above graph, we can see that the highest percentage of deaths occured in 2012, 2013 and 2017.
