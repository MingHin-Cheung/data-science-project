# %% [markdown]
# # Exploratory Data Analysis

# %%
# Import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(".././Dataset/cleaned_data.csv", index_col=0)

# %%
df.head()
# Out:
#          CRASH DATE CRASH TIME   BOROUGH   LATITUDE  LONGITUDE  \
# 1601771  09/18/2013       6:10  BROOKLYN  40.664537 -73.997073
# 1662468  05/31/2013      14:35     BRONX  40.865020 -73.892760
# 1641810  06/15/2013      13:45  BROOKLYN  40.688212 -73.919810
# 1783688  11/04/2012      14:06    QUEENS  40.705641 -73.750470
# 218706   12/31/2019      19:25    QUEENS  40.750095 -73.874910
#
#          NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# 1601771                        1.0                       0.0
# 1662468                        0.0                       0.0
# 1641810                        0.0                       0.0
# 1783688                        1.0                       0.0
# 218706                         1.0                       0.0
#
#          NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# 1601771                              0                             0
# 1662468                              0                             0
# 1641810                              0                             0
# 1783688                              0                             0
# 218706                               1                             0
#
#          NUMBER OF CYCLIST INJURED  NUMBER OF CYCLIST KILLED  \
# 1601771                          1                         0
# 1662468                          0                         0
# 1641810                          0                         0
# 1783688                          0                         0
# 218706                           0                         0
#
#          NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED
# 1601771                           0                          0
# 1662468                           0                          0
# 1641810                           0                          0
# 1783688                           1                          0
# 218706                            0                          0

# %%
df.shape
# Out:
# (34655, 13)

# %%
df.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'LATITUDE', 'LONGITUDE',
#        'NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED',
#        'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED',
#        'NUMBER OF CYCLIST INJURED', 'NUMBER OF CYCLIST KILLED',
#        'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# CRASH DATE                       0
# CRASH TIME                       0
# BOROUGH                          0
# LATITUDE                         0
# LONGITUDE                        0
# NUMBER OF PERSONS INJURED        0
# NUMBER OF PERSONS KILLED         0
# NUMBER OF PEDESTRIANS INJURED    0
# NUMBER OF PEDESTRIANS KILLED     0
# NUMBER OF CYCLIST INJURED        0
# NUMBER OF CYCLIST KILLED         0
# NUMBER OF MOTORIST INJURED       0
# NUMBER OF MOTORIST KILLED        0
# dtype: int64

# %%
#Statistical Summary of our data
df.describe()
# Out:
#            LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  34655.000000  34655.000000               34655.000000
# mean      40.669830    -73.826445                   0.266599
# std        1.452188      2.633621                   0.649524
# min        0.000000    -74.249465                   0.000000
# 25%       40.668648    -73.976333                   0.000000
# 50%       40.717678    -73.928320                   0.000000
# 75%       40.764898    -73.865896                   0.000000
# max       40.912884      0.000000                  22.000000
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              34655.000000                   34655.000000
# mean                   0.001241                       0.060366
# std                    0.043291                       0.249297
# min                    0.000000                       0.000000
# 25%                    0.000000                       0.000000
# 50%                    0.000000                       0.000000
# 75%                    0.000000                       0.000000
# max                    5.000000                       5.000000
#
#        NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  \
# count                  34655.000000               34655.000000
# mean                       0.000577                   0.026663
# std                        0.024017                   0.162702
# min                        0.000000                   0.000000
# 25%                        0.000000                   0.000000
# 50%                        0.000000                   0.000000
# 75%                        0.000000                   0.000000
# max                        1.000000                   2.000000
#
#        NUMBER OF CYCLIST KILLED  NUMBER OF MOTORIST INJURED  \
# count              34655.000000                34655.000000
# mean                   0.000087                    0.178243
# std                    0.009304                    0.600830
# min                    0.000000                    0.000000
# 25%                    0.000000                    0.000000
# 50%                    0.000000                    0.000000
# 75%                    0.000000                    0.000000
# max                    1.000000                   21.000000
#
#        NUMBER OF MOTORIST KILLED
# count               34655.000000
# mean                    0.000548
# std                     0.034392
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     0.000000
# max                     5.000000

# %%
#Checking categorical features in our dataset.

categorical_features = df.select_dtypes(include=[np.object])
categorical_features.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH'], dtype='object')

# %%
#Heatmap of our data

fig, ax = plt.subplots(figsize=(12,6))
sns.heatmap(df.corr(), annot=True, cmap="Reds" )

# %% [markdown]
# __Inference:__ The above heatmap shows the correlation of numerical features in our data. The correlation coefficient is a measure ranging from -1 to 1 (with 1 being the maximum value and -1 being the smallest):<br>
# * The Number closer to zero indicates a lower correlation (precise 0 implying no significant
# relation).
# *	The Number around +1 to one indicates a more positive correlation.
# *	The Number around -1 implies a more negative correlation.

# %%
df.max()
# Out:
# CRASH DATE                          12/31/2020
# CRASH TIME                                9:59
# BOROUGH                          STATEN ISLAND
# LATITUDE                               40.9129
# LONGITUDE                                    0
# NUMBER OF PERSONS INJURED                   22
# NUMBER OF PERSONS KILLED                     5
# NUMBER OF PEDESTRIANS INJURED                5
# NUMBER OF PEDESTRIANS KILLED                 1
# NUMBER OF CYCLIST INJURED                    2
# NUMBER OF CYCLIST KILLED                     1
# NUMBER OF MOTORIST INJURED                  21
# NUMBER OF MOTORIST KILLED                    5
# dtype: object

# %%
df.min()
# Out:
# CRASH DATE                       01/01/2013
# CRASH TIME                             0:00
# BOROUGH                               BRONX
# LATITUDE                                  0
# LONGITUDE                          -74.2495
# NUMBER OF PERSONS INJURED                 0
# NUMBER OF PERSONS KILLED                  0
# NUMBER OF PEDESTRIANS INJURED             0
# NUMBER OF PEDESTRIANS KILLED              0
# NUMBER OF CYCLIST INJURED                 0
# NUMBER OF CYCLIST KILLED                  0
# NUMBER OF MOTORIST INJURED                0
# NUMBER OF MOTORIST KILLED                 0
# dtype: object

# %% [markdown]
# ### Checking skewness ###

# %%
#Checking skewness
df.skew()
# Out:
# LATITUDE                         -27.891204
# LONGITUDE                         27.970370
# NUMBER OF PERSONS INJURED          4.748959
# NUMBER OF PERSONS KILLED          60.024906
# NUMBER OF PEDESTRIANS INJURED      4.441075
# NUMBER OF PEDESTRIANS KILLED      41.592071
# NUMBER OF CYCLIST INJURED          6.056768
# NUMBER OF CYCLIST KILLED         107.469375
# NUMBER OF MOTORIST INJURED         5.912932
# NUMBER OF MOTORIST KILLED        102.815244
# dtype: float64

# %% [markdown]
# ### Checking Kurtosis ###

# %%
#Checking kurtosis
df.kurt()
# Out:
# LATITUDE                           778.218895
# LONGITUDE                          781.168417
# NUMBER OF PERSONS INJURED           60.179683
# NUMBER OF PERSONS KILLED          5553.044791
# NUMBER OF PEDESTRIANS INJURED       24.532922
# NUMBER OF PEDESTRIANS KILLED      1728.000055
# NUMBER OF CYCLIST INJURED           36.112098
# NUMBER OF CYCLIST KILLED         11548.333045
# NUMBER OF MOTORIST INJURED          76.609673
# NUMBER OF MOTORIST KILLED        13461.283455
# dtype: float64

# %% [markdown]
# ### Boroughs with their collision numbers ###

# %%
#Boroughs with their collision numbers
fig, ax = plt.subplots(figsize=(12,6))
sns.countplot(x=df['BOROUGH'], data=df, ax=ax)
plt.show()

# %% [markdown]
# ## Inference:
# - Brooklyn had the most number of collisions as compared to other boroughs while Staten Island had the least.

# %%
#Adding a new column for years
df["CRASH DATE"] = pd.to_datetime(df["CRASH DATE"])
df["year"] = df["CRASH DATE"].dt.year
df["year"].unique()
# Out:
# array([2013, 2012, 2019, 2015, 2017, 2014, 2021, 2020, 2016, 2018],
#       dtype=int64)

# %%
#Adding a month column for months
df["month"] = df["CRASH DATE"].dt.month
df["month"].unique()
# Out:
# array([ 9,  5,  6, 11, 12,  7,  2,  1,  3, 10,  8,  4], dtype=int64)

# %% [markdown]
# ### Checking for number of collisions by year ###

# %%
#Checking for number of collisions by year
fig, ax = plt.subplots(figsize=(12,6))
sns.countplot(x=df['year'], data=df, ax=ax)
plt.show()

# %% [markdown]
# ## Inference:
# - As we can see from this graph, the year 2019 has the most number of collisions where the year 2016 has least.

# %% [markdown]
# ### Checking for number of collisions by month ###

# %%
#Checking for number of collisions by month
fig, ax = plt.subplots(figsize=(12,6))
sns.countplot(x=df['month'], data=df, ax=ax)
plt.show()

# %% [markdown]
# ## Inference:
# - As we can see here, the most number of collisions occured in October overall which is numbered as 10 in this graph.

# %%
#Boroughs with most number of deaths
killed_by_borough = df.groupby("BOROUGH")[["NUMBER OF PERSONS KILLED", "NUMBER OF PEDESTRIANS KILLED",\
                                           "NUMBER OF CYCLIST KILLED"]].sum()
print(killed_by_borough)
killed_by_borough.plot.bar(figsize=(12,6))
# Out:
#                NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS KILLED  \
# BOROUGH
# BRONX                               3.0                             2
# BROOKLYN                           13.0                             7
# MANHATTAN                           6.0                             4
# QUEENS                             19.0                             6
# STATEN ISLAND                       2.0                             1
#
#                NUMBER OF CYCLIST KILLED
# BOROUGH
# BRONX                                 0
# BROOKLYN                              1
# MANHATTAN                             1
# QUEENS                                1
# STATEN ISLAND                         0

# %% [markdown]
# ## Inference:
# - As we can see from the above graph, most deaths occured in Queens and Brooklyn.

# %%
persons_killed_by_year = df.groupby("year")["NUMBER OF PERSONS KILLED"].sum()
persons_killed_by_year
# Out:
# year
# 2012    8.0
# 2013    3.0
# 2014    4.0
# 2015    6.0
# 2016    7.0
# 2017    1.0
# 2018    3.0
# 2019    3.0
# 2020    4.0
# 2021    4.0
# Name: NUMBER OF PERSONS KILLED, dtype: float64

# %% [markdown]
# ### Pie chart for persons killed by year ###

# %%
#Pie chart for persons killed by year
fig, ax  = plt.subplots(figsize=(16, 8))
fig.suptitle('Persons killed by year', size = 14, color = "black")
ax = plt.pie(persons_killed_by_year, labels=persons_killed_by_year.index,
       autopct='%1.0f%%',
       pctdistance=0.9)

# %% [markdown]
# ## Inference:
# - From the above graph, we can see that the highest percentage of deaths occured in 2012, 2013 and 2017.
